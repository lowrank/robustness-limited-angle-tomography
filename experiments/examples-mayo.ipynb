# %%
import sys
import os

import numpy as np

import scipy.io
from matplotlib import pyplot as plt

import torch
import torch.nn as nn

from torch import optim
from torch.utils.data import DataLoader, random_split
import torch.optim.lr_scheduler as lr_scheduler
from tqdm import tqdm

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv_op = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding="same", bias=False),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding="same", bias=False),
            nn.LeakyReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv_op(x)


class DownSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = DoubleConv(in_channels, out_channels)
        self.pool = nn.AvgPool2d(kernel_size=(2,2))

    def forward(self, x):
        down = self.conv(x)
        p = self.pool(down)
        return down, p


class UpSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up   = nn.UpsamplingNearest2d(scale_factor=2)
        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        x = torch.cat([x1, x2], 1)
        return self.conv(x)
    
    
class u_net(nn.Module):
    def __init__(self, in_channels, feat):
        super().__init__()
        self.down_convolution_1 = DownSample(in_channels,   feat)
        self.down_convolution_2 = DownSample(    feat,  2 * feat)
        self.down_convolution_3 = DownSample(2 * feat,  4 * feat)
        self.down_convolution_4 = DownSample(4 * feat,  8 * feat)

        self.bottle_neck        = DoubleConv(8 * feat, 16 * feat)

        self.up_convolution_1 = UpSample(16 * feat + 8 * feat,  8 * feat)
        self.up_convolution_2 = UpSample(8  * feat + 4 * feat,  4 * feat)
        self.up_convolution_3 = UpSample(4  * feat + 2 * feat,  2 * feat)
        self.up_convolution_4 = UpSample(2  * feat +     feat,      feat)

        self.out = nn.Conv2d(in_channels=feat, out_channels=1, kernel_size=1, bias=False)


    def forward(self, x):
        down_1, p1 = self.down_convolution_1(x)
        down_2, p2 = self.down_convolution_2(p1)
        down_3, p3 = self.down_convolution_3(p2)
        down_4, p4 = self.down_convolution_4(p3)

        b = self.bottle_neck(p4)

        up_1 = self.up_convolution_1(b, down_4)
        up_2 = self.up_convolution_2(up_1, down_3)
        up_3 = self.up_convolution_3(up_2, down_2)
        up_4 = self.up_convolution_4(up_3, down_1)

        out = self.out(up_4)
       
        return out
    
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Path to the folder containing .mat files

ANGLE = "100" # visible angle "120", "100", "80"

model100 = u_net(in_channels=1, feat=32).to(device)
model100.load_state_dict(torch.load('./models/model_unet_test_'+ANGLE+'.pth'), strict=True)
model100.eval()
# Out:
# u_net(
#   (down_convolution_1): DownSample(
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (pool): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#   )
#   (down_convolution_2): DownSample(
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (pool): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#   )
#   (down_convolution_3): DownSample(
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (pool): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#   )
#   (down_convolution_4): DownSample(
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#     (pool): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0)
#   )
#   (bottle_neck): DoubleConv(
#     (conv_op): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (up_convolution_1): UpSample(
#     (up): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (up_convolution_2): UpSample(
#     (up): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (up_convolution_3): UpSample(
#     (up): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (up_convolution_4): UpSample(
#     (up): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#     (conv): DoubleConv(
#       (conv_op): Sequential(
#         (0): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (1): LeakyReLU(negative_slope=0.01, inplace=True)
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#         (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#     )
#   )
#   (out): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
# )

# %%
x_mat = scipy.io.loadmat(os.path.join('misc', 'mayo_fbp100'))
x_train = x_mat['H']


y_mat = scipy.io.loadmat(os.path.join('misc', 'mayo_original'))
y_train = y_mat['M']

x_data = torch.tensor(x_train).unsqueeze(dim=0).unsqueeze(dim=0).float().to(device)
y_data = torch.tensor(y_train).unsqueeze(dim=0).unsqueeze(dim=0).float().to(device)

with torch.no_grad():
    
    y_pred_data = model100(x_data)
    
fig = plt.figure()
ax = fig.add_subplot(1, 3, 1)
plt.imshow(y_data[0,0].cpu(),cmap='gray')
plt.axis('off')
ax = fig.add_subplot(1, 3, 2)
plt.imshow(x_data[0,0].cpu(),vmin=0,vmax=1, cmap='gray') 
plt.axis('off')
ax = fig.add_subplot(1, 3, 3)
plt.imshow(y_pred_data[0, 0].cpu(), cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)
